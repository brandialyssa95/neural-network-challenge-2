# %%
# Create a list of at least 10 column names to use as X data
X_data =['Education','Age','DistanceFromHome','JobSatisfaction','EnvironmentSatisfaction','JobInvolvement','OverTime','StockOptionLevel','WorkLifeBalance',
'YearsAtCompany','YearsSinceLastPromotion','NumCompaniesWorked']


# Create X_df using your selected columns
X_df = attrition_df[X_data]

# Show the data types for X_df
X_df.dtypes
# Out:
# Education                   int64
# Age                         int64
# DistanceFromHome            int64
# JobSatisfaction             int64
# EnvironmentSatisfaction     int64
# JobInvolvement              int64
# OverTime                   object
# StockOptionLevel            int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# NumCompaniesWorked          int64
# dtype: object

# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Split the data into training and testing sets
X_df = attrition_df.drop(columns=['Attrition', 'Department'])
y_df = attrition_df[['Attrition', 'Department']]

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_df.head()
# Out:
#    Age     BusinessTravel  DistanceFromHome  Education EducationField  \
# 0   41      Travel_Rarely                 1          2  Life Sciences
# 1   49  Travel_Frequently                 8          1  Life Sciences
# 2   37      Travel_Rarely                 2          2          Other
# 3   33  Travel_Frequently                 3          4  Life Sciences
# 4   27      Travel_Rarely                 2          1        Medical
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#                  JobRole  ...  PerformanceRating RelationshipSatisfaction  \
# 0        Sales Executive  ...                  3                        1
# ...

# %%
# Create a StandardScaler
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instance
scaler = StandardScaler()
# Fit the StandardScaler to the training data
df_train = pd.get_dummies(X_df)
# Scale the training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_color_train, y_color_test, y_quality_train, y_quality_test = train_test_split(X_df, y_color, y_quality)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-8aa73fdc4ffb> in <cell line: 10>()
#       8 # Scale the training and testing data
#       9 from sklearn.model_selection import train_test_split
# ---> 10 X_train, X_test, y_color_train, y_color_test, y_quality_train, y_quality_test = train_test_split(X_df, y_color, y_quality)
#      11
#      12
#
# NameError: name 'y_color' is not defined

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder for the Department column
enc = OneHotEncoder(sparse=False)

# Fit the encoder to the training data
X_train_enc = enc.fit(X_train)
# Create two new variables by applying the encoder
# to the training and testing data

y_train_dept_trans = dept_encoder.transform(y_train[['Department']])
y_test_dept_trans = dept_encoder.transform(y_test[['Department']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3e4b7488bfa0> in <cell line: 12>()
#      10 # to the training and testing data
#      11
# ---> 12 y_train_dept_trans = dept_encoder.transform(y_train[['Department']])
#      13 y_test_dept_trans = dept_encoder.transform(y_test[['Department']])
#
# NameError: name 'dept_encoder' is not defined

# %%
# Create a OneHotEncoder for the Attrition column
dept_encoder = OneHotEncoder(sparse=False)

# Fit the encoder to the training data
from sklearn.preprocessing import OneHotEncoder
y_train_att_enc = dept_encoder.fit(y_train[['Attrition']])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_att_trans = dept_encoder.transform(y_train[['Attrition']])
y_test_att_trans = dept_encoder.transform(y_test[['Attrition']])
y_train_att_trans[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-192453d6d178> in <cell line: 6>()
#       4 # Fit the encoder to the training data
#       5 from sklearn.preprocessing import OneHotEncoder
# ----> 6 y_train_att_enc = dept_encoder.fit(y_train[['Attrition']])
#       7
#       8 # Create two new variables by applying the encoder
#
# NameError: name 'y_train' is not defined

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
columns = X_train.shape[1]
columns

# Create the input layer
input = layers.Input(shape=(columns,))

# Create at least two shared layers

# %%
# Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
layer1 = layers.Dense(units=10, activation='relu')(input)
layer2 = layers.Dense(units=10, activation='relu')(layer1)

# Create the output layer
quality_output = layers.Dense(units=1, activation='sigmoid')(layer2)

# %%
# Create the model
model = Model(inputs=input, outputs=quality_output)

# Compile the model
model.Compile(optimizer= 'adam',
              loss= {'quality_output': 'categorical_crossentropy', 'color_output':  'binary_crossentropy'},
              metrics=['quality_output', 'accuracy', 'color_output'] )

# Summarize the model
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-c79dbdce02c4> in <cell line: 5>()
#       3
#       4 # Compile the model
# ----> 5 model.Compile(optimizer= 'adam',
#       6               loss= {'quality_output': 'categorical_crossentropy', 'color_output':  'binary_crossentropy'},
#       7               metrics=['quality_output', 'accuracy', 'color_output'] )
#
# AttributeError: 'Functional' object has no attribute 'Compile'

# %%
# Train the model
train_test_split(X_df, y_df, random_state=1)
# Out:
# [      Age     BusinessTravel  DistanceFromHome  Education    EducationField  \
#  464    37      Travel_Rarely                 1          3  Technical Degree
#  512    27      Travel_Rarely                 3          4           Medical
#  480    30  Travel_Frequently                12          4     Life Sciences
#  680    36      Travel_Rarely                 7          4             Other
#  1023   56      Travel_Rarely                 1          2     Life Sciences
#  ...   ...                ...               ...        ...               ...
#  715    33  Travel_Frequently                 1          4             Other
#  905    29      Travel_Rarely                 1          3     Life Sciences
#  1096   40      Travel_Rarely                 6          2           Medical
#  235    43      Travel_Rarely                16          3         Marketing
#  1061   24         Non-Travel                13          2     Life Sciences
#
# ...

# %%
# Evaluate the model with the testing data
test_results = model.evaluate(X_test, {'quality_output': y_quality_test, 'color_output': y_color_test})
test_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a9714b967a21> in <cell line: 2>()
#       1 # Evaluate the model with the testing data
# ----> 2 test_results = model.evaluate(X_test, {'quality_output': y_quality_test, 'color_output': y_color_test})
#       3 test_results
#
# NameError: name 'X_test' is not defined

# %%
# Print the accuracy for both department and attrition
print(f"Department Accuracy: {test_results[1]}")
print(f"Attrition Accuracy: {test_results[2]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-54e1770c544d> in <cell line: 2>()
#       1 # Print the accuracy for both department and attrition
# ----> 2 print(f"Department Accuracy: {test_results[1]}")
#       3 print(f"Attrition Accuracy: {test_results[2]}")
#
# NameError: name 'test_results' is not defined

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1.
# 2.
# 3.
